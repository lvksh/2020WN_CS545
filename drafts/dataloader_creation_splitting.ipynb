# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import pandas as pd
import os
import numpy as np
import datetime


def getThreshold(stock_id_list, daily_path):
    rise_pct = []
    for stk_id in stock_id_list:
      string = daily_path+'/'+stk_id+'.csv'
      daily_data = pd.read_csv(string, sep = '\t')
      diff = list(daily_data.open.diff(-1))
      stk_rise_pct = diff[:len(diff)-1] / daily_data.open[1:] * 100
      rise_pct.extend(stk_rise_pct)
      # print(f'{stk_id} finished!\n')
    UP_parm = np.quantile(rise_pct, 0.67)
    DOWN_parm = np.quantile(rise_pct, 0.33)
    return UP_parm, DOWN_parm

## add the classfication label to a stock for each date
def daily_label(stock_id, daily_path, UP_parm, DOWN_parm):
    try:
        string = daily_path+'/'+stock_id+'.csv'
        # daily_eg = pd.read_csv(string)
        daily_eg = pd.read_csv(string, sep = '\t')
    except:
        print('file not exist!')
    diff = list(daily_eg.open.diff(-1))
    diff = [float('inf')] + diff[:len(diff)-1]
    daily_eg['rise_pct'] = diff / daily_eg.open*100
    daily_eg['label'] = 'PRESERVE'
    daily_eg.loc[daily_eg['rise_pct']>UP_parm, 'label'] = 'UP'
    daily_eg.loc[daily_eg['rise_pct']<DOWN_parm, 'label'] = 'DOWN'
    daily_eg['date'] = pd.to_datetime(daily_eg['trade_date'], format='%Y%m%d')
    return daily_eg.loc[daily_eg['trade_date']<20201014]


## build Dataloader for all stocks
def buildDataloader(stock_id_list, daily_path, news_path, UP_parm, DOWN_parm):
    dataloader = pd.DataFrame()
    N = len(stock_id_list)
    for ct, stock_id in enumerate(stock_id_list):
        daily_data = daily_label(stock_id,daily_path, UP_parm, DOWN_parm)
        date_list = [i.strftime("%Y-%m-%d") for i in daily_data.date]
        date_list.reverse()
        moving_date_list = [date_list[i:i+11] for i in range(0, len(date_list)-11+1)]
        df_id = pd.DataFrame()
        for Ndayslist in moving_date_list:
            dayslist = Ndayslist[:len(Ndayslist)-1]
            day = Ndayslist[-1]
            lastday = Ndayslist[-2]
            trade_day = int(day[:4]+day[5:7]+day[8:10])
            last_day = int(lastday[:4]+lastday[5:7]+lastday[8:10])
            cur_label = list(daily_data.loc[daily_data['trade_date']==trade_day].label)
            ## 现在还没有数值特征数据
            # stats_10 = daily_data.loc[daily_data['trade_date']==last_day,['EMA10', 'turnoverrate10', 'volatilityratio10']]
            # numeric_stats = stats_10.values[0].tolist()
            numeric_stats = [float('nan')]*3
            entity = []
            for date in dayslist:
                if os.path.isfile(news_path+f'{stock_id}/{date}.txt'):
                    entity.append(f'{stock_id}/{date}.txt')
                else:
                    entity.append(float('nan'))
            df_entity = pd.DataFrame(entity)
            #if int(df_entity.isna().sum()) == 10:
            #    print('stock_id: ', stock_id, 'contains no news to predict the label at date ', str(trade_day))
            #    continue
            df_id = df_id.append(pd.DataFrame([stock_id]+[trade_day]+entity+numeric_stats+cur_label).transpose())
        dataloader = dataloader.append(df_id)
        print('stock:', stock_id, ' finished!')
        print(N-ct-1, ' stocks left.')
        print('------------------------------')
    dataloader.columns = ['stock_id','label_date','day-1','day-2','day-3','day-4','day-5','day-6','day-7','day-8',
                          'day-9','day-10','EMA10','turnoverrate10', 'volatilityratio10','label']
    dataloader.reset_index(inplace = True, drop = True)
    return dataloader


def write_dataloader(dataloader, Ptrain, Pcv, outputpath):
    random.seed(50)
    dataloader.sort_values(by='label_date')
    
    n = dataloader.shape[0]
    train_num = int(n*Ptrain)
    cv_num = int(n*Pcv)

    train = dataloader[:train_num]
    cv = dataloader[train_num:train_num+cv_num]
    test = dataloader[cv_num+train_num:]
    
    if not os.path.isdir(outputpath):
        os.mkdir(outputpath)
    train.to_csv(outputpath+'/train_data.csv', index=False)
    cv.to_csv(outputpath+'/cv_data.csv', index=False)
    test.to_csv(outputpath+'/test_data.csv', index=False)
    print('Successfully created training, cv and test dataset!')
    # return train, cv, test

# %%
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'stockDataFromTushare545'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
# print(os.listdir(GOOGLE_DRIVE_PATH+'/daily/'))

# %%
## example
UP_parm = 0.77618351
DOWN_parm = -0.71681229
## 先做300个
stock300 = pd.read_csv(GOOGLE_DRIVE_PATH+'/stockid2name.csv')
stock_id_list = list(stock300.id)
daily_path = GOOGLE_DRIVE_PATH+'/daily/'
news_path = GOOGLE_DRIVE_PATH+'/stockNews/'
outputpath = GOOGLE_DRIVE_PATH+'/dataloader/'
Ptrain = 0.67
Pcv = 0.1
df_dataloader = buildDataloader(stock_id_list, daily_path, news_path, UP_parm, DOWN_parm)
write_dataloader(df_dataloader, Ptrain, Pcv, outputpath)
# Out:
# stock: sz000001  finished!
# 299  stocks left.
# ------------------------------
# stock: sz000002  finished!
# 298  stocks left.
# ------------------------------
# stock: sz000063  finished!
# 297  stocks left.
# ------------------------------
# stock: sz000066  finished!
# 296  stocks left.
# ------------------------------
# stock: sz000069  finished!
# 295  stocks left.
# ------------------------------
# stock: sz000100  finished!
# 294  stocks left.
# ------------------------------
# stock: sz000157  finished!
# 293  stocks left.
# ------------------------------
# stock: sz000166  finished!
# 292  stocks left.
# ------------------------------
# stock: sz000333  finished!
# 291  stocks left.
# ------------------------------
# stock: sz000338  finished!
# 290  stocks left.
# ------------------------------
# stock: sz000425  finished!
# 289  stocks left.
# ------------------------------
# stock: sz000538  finished!
# 288  stocks left.
# ------------------------------
# stock: sz000568  finished!
# 287  stocks left.
# ------------------------------
# stock: sz000596  finished!
# 286  stocks left.
# ------------------------------
# stock: sz000625  finished!
# 285  stocks left.
# ------------------------------
# stock: sz000627  finished!
# 284  stocks left.
# ------------------------------
# stock: sz000651  finished!
# 283  stocks left.
# ------------------------------
# stock: sz000656  finished!
# 282  stocks left.
# ------------------------------
# stock: sz000661  finished!
# 281  stocks left.
# ------------------------------
# stock: sz000671  finished!
# 280  stocks left.
# ------------------------------
# stock: sz000703  finished!
# 279  stocks left.
# ------------------------------
# stock: sz000708  finished!
# 278  stocks left.
# ------------------------------
# stock: sz000709  finished!
# 277  stocks left.
# ------------------------------
# stock: sz000723  finished!
# 276  stocks left.
# ------------------------------
# stock: sz002508  finished!
# 225  stocks left.
# ------------------------------
# stock: sz002555  finished!
# 224  stocks left.
# ------------------------------
# stock: sz002558  finished!
# 223  stocks left.
# ------------------------------
# stock: sz002594  finished!
# 222  stocks left.
# ------------------------------
# stock: sz002601  finished!
# 221  stocks left.
# ------------------------------
# stock: sz002602  finished!
# 220  stocks left.
# ------------------------------
# stock: sz002607  finished!
# 219  stocks left.
# ------------------------------
# stock: sz002624  finished!
# 218  stocks left.
# ------------------------------
# stock: sz002673  finished!
# 217  stocks left.
# ------------------------------
# stock: sz002714  finished!
# 216  stocks left.
# ------------------------------
# stock: sz002736  finished!
# 215  stocks left.
# ------------------------------
# stock: sz002739  finished!
# 214  stocks left.
# ------------------------------
# stock: sz002773  finished!
# 213  stocks left.
# ------------------------------
# stock: sz002841  finished!
# 212  stocks left.
# ------------------------------
# stock: sz002916  finished!
# 211  stocks left.
# ------------------------------
# stock: sz002938  finished!
# 210  stocks left.
# ------------------------------
# stock: sz002939  finished!
# 209  stocks left.
# ------------------------------
# stock: sz002945  finished!
# 208  stocks left.
# ------------------------------
# stock: sz002958  finished!
# 207  stocks left.
# ------------------------------
# stock: sz003816  finished!
# 206  stocks left.
# ------------------------------
# stock: sz300003  finished!
# 205  stocks left.
# ------------------------------
# stock: sz300014  finished!
# 204  stocks left.
# ------------------------------
# stock: sz300015  finished!
# 203  stocks left.
# ------------------------------
# stock: sz300033  finished!
# 202  stocks left.
# ------------------------------
# stock: sz300059  finished!
# 201  stocks left.
# ------------------------------
# stock: sz300122  finished!
# 200  stocks left.
# ------------------------------
# stock: sz300124  finished!
# 199  stocks left.
# ------------------------------
# stock: sz300136  finished!
# 198  stocks left.
# ------------------------------
# stock: sz300142  finished!
# 197  stocks left.
# ------------------------------
# stock: sz300144  finished!
# 196  stocks left.
# ------------------------------
# stock: sz300347  finished!
# 195  stocks left.
# ------------------------------
# stock: sz300408  finished!
# 194  stocks left.
# ------------------------------
# stock: sz300413  finished!
# 193  stocks left.
# ------------------------------
# stock: sz300433  finished!
# 192  stocks left.
# ------------------------------
# stock: sz300498  finished!
# 191  stocks left.
# ------------------------------
# stock: sz300601  finished!
# 190  stocks left.
# ------------------------------
# stock: sz300628  finished!
# 189  stocks left.
# ------------------------------
# stock: sh600000  finished!
# 188  stocks left.
# ------------------------------
# stock: sh600004  finished!
# 187  stocks left.
# ------------------------------
# stock: sh600009  finished!
# 186  stocks left.
# ------------------------------
# stock: sh600010  finished!
# 185  stocks left.
# ------------------------------
# stock: sh600011  finished!
# 184  stocks left.
# ------------------------------
# stock: sh600015  finished!
# 183  stocks left.
# ------------------------------
# stock: sh600016  finished!
# 182  stocks left.
# ------------------------------
# stock: sh600018  finished!
# 181  stocks left.
# ------------------------------
# stock: sh600019  finished!
# 180  stocks left.
# ------------------------------
# stock: sh600025  finished!
# 179  stocks left.
# ------------------------------
# stock: sh600027  finished!
# 178  stocks left.
# ------------------------------
# stock: sh600028  finished!
# 177  stocks left.
# ------------------------------
# stock: sh600029  finished!
# 176  stocks left.
# ------------------------------
# stock: sh600030  finished!
# 175  stocks left.
# ------------------------------
# stock: sh600031  finished!
# 174  stocks left.
# ------------------------------
# stock: sh600036  finished!
# 173  stocks left.
# ------------------------------
# stock: sh600038  finished!
# 172  stocks left.
# ------------------------------
# stock: sh600048  finished!
# 171  stocks left.
# ------------------------------
# stock: sh600050  finished!
# 170  stocks left.
# ------------------------------
# stock: sh600061  finished!
# 169  stocks left.
# ------------------------------
# stock: sh600066  finished!
# 168  stocks left.
# ------------------------------
# stock: sh600068  finished!
# 167  stocks left.
# ------------------------------
# stock: sh600085  finished!
# 166  stocks left.
# ------------------------------
# stock: sh600089  finished!
# 165  stocks left.
# ------------------------------
# stock: sh600104  finished!
# 164  stocks left.
# ------------------------------
# stock: sh600109  finished!
# 163  stocks left.
# ------------------------------
# stock: sh600111  finished!
# 162  stocks left.
# ------------------------------
# stock: sh600115  finished!
# 161  stocks left.
# ------------------------------
# stock: sh600118  finished!
# 160  stocks left.
# ------------------------------
# stock: sh600170  finished!
# 159  stocks left.
# ------------------------------
# stock: sh600176  finished!
# 158  stocks left.
# ------------------------------
# stock: sh600177  finished!
# 157  stocks left.
# ------------------------------
# stock: sh600183  finished!
# 156  stocks left.
# ------------------------------
# stock: sh600188  finished!
# 155  stocks left.
# ------------------------------
# stock: sh600196  finished!
# 154  stocks left.
# ------------------------------
# stock: sh600208  finished!
# 153  stocks left.
# ------------------------------
# stock: sh600219  finished!
# 152  stocks left.
# ------------------------------
# stock: sh600221  finished!
# 151  stocks left.
# ------------------------------
# stock: sh600233  finished!
# 150  stocks left.
# ------------------------------
# stock: sh600271  finished!
# 149  stocks left.
# ------------------------------
# stock: sh600276  finished!
# 148  stocks left.
# ------------------------------
# stock: sh600297  finished!
# 147  stocks left.
# ------------------------------
# stock: sh600299  finished!
# 146  stocks left.
# ------------------------------
# stock: sh600309  finished!
# 145  stocks left.
# ------------------------------
# stock: sh600332  finished!
# 144  stocks left.
# ------------------------------
# stock: sh600340  finished!
# 143  stocks left.
# ------------------------------
# stock: sh600346  finished!
# 142  stocks left.
# ------------------------------
# stock: sh600352  finished!
# 141  stocks left.
# ------------------------------
# stock: sh600362  finished!
# 140  stocks left.
# ------------------------------
# stock: sh600369  finished!
# 139  stocks left.
# ------------------------------
# stock: sh600372  finished!
# 138  stocks left.
# ------------------------------
# stock: sh600383  finished!
# 137  stocks left.
# ------------------------------
# stock: sh600390  finished!
# 136  stocks left.
# ------------------------------
# stock: sh600398  finished!
# 135  stocks left.
# ------------------------------
# stock: sh600406  finished!
# 134  stocks left.
# ------------------------------
# stock: sh600436  finished!
# 133  stocks left.
# ------------------------------
# stock: sh600438  finished!
# 132  stocks left.
# ------------------------------
# stock: sh600482  finished!
# 131  stocks left.
# ------------------------------
# stock: sh600487  finished!
# 130  stocks left.
# ------------------------------
# stock: sh600489  finished!
# 129  stocks left.
# ------------------------------
# stock: sh600498  finished!
# 128  stocks left.
# ------------------------------
# stock: sh600516  finished!
# 127  stocks left.
# ------------------------------
# stock: sh600519  finished!
# 126  stocks left.
# ------------------------------
# stock: sh600522  finished!
# 125  stocks left.
# ------------------------------
# stock: sh600547  finished!
# 124  stocks left.
# ------------------------------
# stock: sh600570  finished!
# 123  stocks left.
# ------------------------------
# stock: sh600583  finished!
# 122  stocks left.
# ------------------------------
# stock: sh600585  finished!
# 121  stocks left.
# ------------------------------
# stock: sh600588  finished!
# 120  stocks left.
# ------------------------------
# stock: sh600606  finished!
# 119  stocks left.
# ------------------------------
# stock: sh600637  finished!
# 118  stocks left.
# ------------------------------
# stock: sh600655  finished!
# 117  stocks left.
# ------------------------------
# stock: sh600660  finished!
# 116  stocks left.
# ------------------------------
# stock: sh600674  finished!
# 115  stocks left.
# ------------------------------
# stock: sh600690  finished!
# 114  stocks left.
# ------------------------------
# stock: sh600703  finished!
# 113  stocks left.
# ------------------------------
# stock: sh600705  finished!
# 112  stocks left.
# ------------------------------
# stock: sh600741  finished!
# 111  stocks left.
# ------------------------------
# stock: sh600745  finished!
# 110  stocks left.
# ------------------------------
# stock: sh600760  finished!
# 109  stocks left.
# ------------------------------
# stock: sh600795  finished!
# 108  stocks left.
# ------------------------------
# stock: sh600809  finished!
# 107  stocks left.
# ------------------------------
# stock: sh600837  finished!
# 106  stocks left.
# ------------------------------
# stock: sh600848  finished!
# 105  stocks left.
# ------------------------------
# stock: sh600867  finished!
# 104  stocks left.
# ------------------------------
# stock: sh600886  finished!
# 103  stocks left.
# ------------------------------
# stock: sh600887  finished!
# 102  stocks left.
# ------------------------------
# stock: sh600893  finished!
# 101  stocks left.
# ------------------------------
# stock: sh600900  finished!
# 100  stocks left.
# ------------------------------
# stock: sh600919  finished!
# 99  stocks left.
# ------------------------------
# stock: sh600926  finished!
# 98  stocks left.
# ------------------------------
# stock: sh600928  finished!
# 97  stocks left.
# ------------------------------
# stock: sh600958  finished!
# 96  stocks left.
# ------------------------------
# stock: sh600968  finished!
# 95  stocks left.
# ------------------------------
# stock: sh600977  finished!
# 94  stocks left.
# ------------------------------
# stock: sh600989  finished!
# 93  stocks left.
# ------------------------------
# stock: sh600998  finished!
# 92  stocks left.
# ------------------------------
# stock: sh600999  finished!
# 91  stocks left.
# ------------------------------
# stock: sh601006  finished!
# 90  stocks left.
# ------------------------------
# stock: sh601009  finished!
# 89  stocks left.
# ------------------------------
# stock: sh601012  finished!
# 88  stocks left.
# ------------------------------
# stock: sh601018  finished!
# 87  stocks left.
# ------------------------------
# stock: sh601021  finished!
# 86  stocks left.
# ------------------------------
# stock: sh601066  finished!
# 85  stocks left.
# ------------------------------
# stock: sh601077  finished!
# 84  stocks left.
# ------------------------------
# stock: sh601088  finished!
# 83  stocks left.
# ------------------------------
# stock: sh601100  finished!
# 82  stocks left.
# ------------------------------
# stock: sh601108  finished!
# 81  stocks left.
# ------------------------------
# stock: sh601111  finished!
# 80  stocks left.
# ------------------------------
# stock: sh601117  finished!
# 79  stocks left.
# ------------------------------
# stock: sh601138  finished!
# 78  stocks left.
# ------------------------------
# stock: sh601155  finished!
# 77  stocks left.
# ------------------------------
# stock: sh601162  finished!
# 76  stocks left.
# ------------------------------
# stock: sh601166  finished!
# 75  stocks left.
# ------------------------------
# stock: sh601169  finished!
# 74  stocks left.
# ------------------------------
# stock: sh601186  finished!
# 73  stocks left.
# ------------------------------
# stock: sh601198  finished!
# 72  stocks left.
# ------------------------------
# stock: sh601211  finished!
# 71  stocks left.
# ------------------------------
# stock: sh601212  finished!
# 70  stocks left.
# ------------------------------
# stock: sh601216  finished!
# 69  stocks left.
# ------------------------------
# stock: sh601225  finished!
# 68  stocks left.
# ------------------------------
# stock: sh601229  finished!
# 67  stocks left.
# ------------------------------
# stock: sh601231  finished!
# 66  stocks left.
# ------------------------------
# stock: sh601236  finished!
# 65  stocks left.
# ------------------------------
# stock: sh601238  finished!
# 64  stocks left.
# ------------------------------
# stock: sh601288  finished!
# 63  stocks left.
# ------------------------------
# stock: sh601298  finished!
# 62  stocks left.
# ------------------------------
# stock: sh601318  finished!
# 61  stocks left.
# ------------------------------
# stock: sh601319  finished!
# 60  stocks left.
# ------------------------------
# stock: sh601328  finished!
# 59  stocks left.
# ------------------------------
# stock: sh601336  finished!
# 58  stocks left.
# ------------------------------
# stock: sh601360  finished!
# 57  stocks left.
# ------------------------------
# stock: sh601377  finished!
# 56  stocks left.
# ------------------------------
# stock: sh601390  finished!
# 55  stocks left.
# ------------------------------
# stock: sh601398  finished!
# 54  stocks left.
# ------------------------------
# stock: sh601555  finished!
# 53  stocks left.
# ------------------------------
# stock: sh601577  finished!
# 52  stocks left.
# ------------------------------
# stock: sh601600  finished!
# 51  stocks left.
# ------------------------------
# stock: sh601601  finished!
# 50  stocks left.
# ------------------------------
# stock: sh601607  finished!
# 49  stocks left.
# ------------------------------
# stock: sh601618  finished!
# 48  stocks left.
# ------------------------------
# stock: sh601628  finished!
# 47  stocks left.
# ------------------------------
# stock: sh601633  finished!
# 46  stocks left.
# ------------------------------
# stock: sh601658  finished!
# 45  stocks left.
# ------------------------------
# stock: sh601668  finished!
# 44  stocks left.
# ------------------------------
# stock: sh601669  finished!
# 43  stocks left.
# ------------------------------
# stock: sh601688  finished!
# 42  stocks left.
# ------------------------------
# stock: sh601698  finished!
# 41  stocks left.
# ------------------------------
# stock: sh601727  finished!
# 40  stocks left.
# ------------------------------
# stock: sh601766  finished!
# 39  stocks left.
# ------------------------------
# stock: sh601788  finished!
# 38  stocks left.
# ------------------------------
# stock: sh601800  finished!
# 37  stocks left.
# ------------------------------
# stock: sh601808  finished!
# 36  stocks left.
# ------------------------------
# stock: sh601816  finished!
# 35  stocks left.
# ------------------------------
# stock: sh601818  finished!
# 34  stocks left.
# ------------------------------
# stock: sh601828  finished!
# 33  stocks left.
# ------------------------------
# stock: sh601838  finished!
# 32  stocks left.
# ------------------------------
# stock: sh601857  finished!
# 31  stocks left.
# ------------------------------
# stock: sh601877  finished!
# 30  stocks left.
# ------------------------------
# stock: sh601878  finished!
# 29  stocks left.
# ------------------------------
# stock: sh601881  finished!
# 28  stocks left.
# ------------------------------
# stock: sh601888  finished!
# 27  stocks left.
# ------------------------------
# stock: sh601898  finished!
# 26  stocks left.
# ------------------------------
# stock: sh601899  finished!
# 25  stocks left.
# ------------------------------
# stock: sh601901  finished!
# 24  stocks left.
# ------------------------------
# stock: sh601916  finished!
# 23  stocks left.
# ------------------------------
# stock: sh601919  finished!
# 22  stocks left.
# ------------------------------
# stock: sh601933  finished!
# 21  stocks left.
# ------------------------------
# stock: sh601939  finished!
# 20  stocks left.
# ------------------------------
# stock: sh601985  finished!
# 19  stocks left.
# ------------------------------
# stock: sh601988  finished!
# 18  stocks left.
# ------------------------------
# stock: sh601989  finished!
# 17  stocks left.
# ------------------------------
# stock: sh601992  finished!
# 16  stocks left.
# ------------------------------
# stock: sh601997  finished!
# 15  stocks left.
# ------------------------------
# stock: sh601998  finished!
# 14  stocks left.
# ------------------------------
# stock: sh603019  finished!
# 13  stocks left.
# ------------------------------
# stock: sh603156  finished!
# 12  stocks left.
# ------------------------------
# stock: sh603160  finished!
# 11  stocks left.
# ------------------------------
# stock: sh603259  finished!
# 10  stocks left.
# ------------------------------
# stock: sh603260  finished!
# 9  stocks left.
# ------------------------------
# stock: sh603288  finished!
# 8  stocks left.
# ------------------------------
# stock: sh603369  finished!
# 7  stocks left.
# ------------------------------
# stock: sh603501  finished!
# 6  stocks left.
# ------------------------------
# stock: sh603658  finished!
# 5  stocks left.
# ------------------------------
# stock: sh603799  finished!
# 4  stocks left.
# ------------------------------
# stock: sh603833  finished!
# 3  stocks left.
# ------------------------------
# stock: sh603899  finished!
# 2  stocks left.
# ------------------------------
# stock: sh603986  finished!
# 1  stocks left.
# ------------------------------
# stock: sh603993  finished!
# 0  stocks left.
# ------------------------------
# Successfully created training, cv and test dataset!

# %%
# write_dataloader(df_dataloader, Ptrain, Pcv, outputpath)
cvfile = pd.read_csv(GOOGLE_DRIVE_PATH+'/dataloader/cv_data.csv')
cvfile.head()
# Out:
#    stock_id  label_date  ... volatilityratio10     label
# 0  sh600900    20190128  ...               NaN  PRESERVE
# 1  sh600900    20190129  ...               NaN        UP
# 2  sh600900    20190130  ...               NaN  PRESERVE
# 3  sh600900    20190131  ...               NaN        UP
# 4  sh600900    20190201  ...               NaN      DOWN
#
# [5 rows x 16 columns]

# %%
np.quantile(pct,[0.33,0.67])
# Out:
# array([-0.71681229,  0.77618351])

# %%
import jieba,math
import jieba.analyse
import re
import pickle
import gensim

## get stopword list
f = open(GOOGLE_DRIVE_PATH + '/Stopwords/stopwords.pkl', 'rb')
stopwords = pickle.load(f)
f.close()

## get pretrained word2vec model
word2vecPath =  GOOGLE_DRIVE_PATH + '/ChineseWord2Vec/sgns.financial.word'
word2vec = gensim.models.KeyedVectors.load_word2vec_format(word2vecPath, binary=False)


## class dataset dataloader
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, datafile, word2vec, newspath, stopwords, max_size):
        self.dataset = pd.read_csv(datafile)
        self.stopwords = stopwords
        self.max_size = max_sizr
        self.word2vec = wordvec
        
    def __get_item__(self, index):
        news_list, label = self.dataset[index,2:-1], self.dataset[index,-1]
        
        ## 返回10天新闻文本得到的1个词向量
        def convert2vec(news_list):
            
            def preProcess(raw_data):
                raw_text = pd.read_csv(raw_data, header=None)
                news_data = []
                for i in range(len(raw_text)):
                    text = str(raw_data.iloc[i,:])
                    str_text = text.split('\n')[0]
                    tokens = jieba.lcut(str_text,cut_all=False)
                    cleanword = []
                    for wd in tokens:
                      if wd not in self.stopwords:
                        cleanword.append(wd)
                    news_data.append(cleanword)
                return news_data

            def wd2vec(news_data):
                model = self.word2vec
                vec_list = []
                for wd_list in news_data:
                  for wd in wd_list:
                    clean_vec = np.zeros(self.max_size)
                    if wd in model.vocab:
                      clean_vec += model.get_vector(wd)
                  vec_list.append(clean_vec)
                return vec_list

            def combineVec(vec_list):
              ## implement attetion layer for 10 days' news

            #------
            news_vec_list = []   ## 用来存每天的新闻词向量
            for news_path in news_list:
                if np.isnan(news_path):
                    continue
                else:
                    news_raw_data = pd.read_csv(news_path) ## 读入某天的新闻文本
                    news_data = preProcess(news_raw_data)  ## 预处理新闻文本：分词，去停用词等等
                    news_word2vec = wd2vec(news_data)    ## 对处理后的文本词向量化
                    news_vec_list.append(news_word2vec)    
            news_vec = combineVec(news_vec_list)           ## 对10天的词向量列表整合成一个词向量
            return news_vec
        
        
        news_vec = convert2vec(news_list)
        return news_vec, label
            
        
        
    def __len__():

# %%
import pickle
f = open(GOOGLE_DRIVE_PATH + '/Stopwords/stopwords.pkl', 'rb')
stopwords = pickle.load(f)
f.close()
raw_data = pd.read_csv(GOOGLE_DRIVE_PATH + '/stockNews/' + cvfile.iloc[0,5], header=None)

# %%
raw_data
# Out:
# 0

# %%
import jieba,math
import jieba.analyse
import re
text = str(raw_data.iloc[2,:])
str_text = text.split('\n')[0]

#精准模式cut_all=False，默认即是
str_jing1=jieba.lcut(str_text,cut_all=False)
cleanword = []
for wd in str_jing1:
  if wd not in stopwords:
    cleanword.append(wd)
print(cleanword)

#搜索引擎模式  cut_for_search

# str_soso1=jieba.cut_for_search(str_text)
# print('搜索引擎分词：{ %d}' % len(list(str_soso1)))
# str_soso2=jieba.cut_for_search(str_text)
# print("/".join(str_soso2))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.911 seconds.
# Prefix dict has been built successfully.
# ['长江', '电力', '2018', '年度', '净利润', '226.30', '亿元', '同比', '增长', '1.66%', '长江', '电力', '2018', '年度', '净']

# %%
import gensim
word2vecPath =  GOOGLE_DRIVE_PATH + '/ChineseWord2Vec/sgns.financial.word'
word2vec = gensim.models.KeyedVectors.load_word2vec_format(word2vecPath, binary=False)

# %%
            def preProcess(raw_data):
                # raw_text = pd.read_csv(raw_data, header=None)
                raw_text = raw_data
                news_data = []
                for i in range(len(raw_text)):
                    text = str(raw_data.iloc[i,:])
                    str_text = text.split('\n')[0]
                    tokens = jieba.lcut(str_text,cut_all=False)
                    cleanword = []
                    for wd in tokens:
                      if wd not in stopwords:
                        cleanword.append(wd)
                    news_data.append(cleanword)
                return news_data

            def wd2vec(news_data):
                model = word2vec
                max_size = 300
                vec_list = []
                for wd_list in news_data:
                  for wd in wd_list:
                    clean_vec = np.zeros(max_size)
                    if wd in model.vocab:
                      clean_vec += model.get_vector(wd)
                  vec_list.append(clean_vec)
                return vec_list

